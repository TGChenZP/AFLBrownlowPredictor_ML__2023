# %%
import pandas as pd
import copy
import time
import numpy as np
import random
import pickle

from sklearn.metrics import r2_score, mean_absolute_percentage_error, mean_squared_error
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, balanced_accuracy_score

# %%
class JiXi:



    def __init__(self):
        """ Initialise class """
        self._initialise_objects()

        print('JiXi Initialised')



    def _initialise_objects(self):
        """ Helper to initialise objects """

        self.train_x = None
        self.train_y = None
        self.val_x = None
        self.val_y = None
        self.test_x = None
        self.test_y = None
        self.tuning_result = None
        self.model = None
        self.parameter_choices = None
        self.hyperparameters = None
        self.checked = None
        self.result = None
        self.tuning_result_saving_address = None
        self.object_saving_address = None
        self._up_to = 0
        self._seed = 19421221
        self.best_score = -np.inf
        self.best_combo = None
        self.best_clf = None
        self.clf_type = None
        self.combos = None
        self.n_items = None
        self.outmost_layer = None
        self._core = None
        self._relative_combos = None
        self._both_combos = None
        self._dealt_with = None
        self._pos_neg_combos = None
        self._abs_max = None
        self._new_combos = None

        self.regression_extra_output_columns = ['Train r2', 'Val r2', 'Test r2', 
            'Train RMSE', 'Val RMSE', 'Test RMSE', 'Train MAPE', 'Val MAPE', 'Test MAPE', 'Time']
        self.classification_extra_output_columns = ['Train accu', 'Val accu', 'Test accu', 
            'Train balanced_accu', 'Val balanced_accu', 'Test balanced_accu', 'Train f1', 'Val f1', 'Test f1', 
            'Train precision', 'Val precision', 'Test precision', 'Train recall', 'Val recall', 'Test recall', 'Time']

        

    def read_in_data(self, train_x, train_y, val_x, val_y, test_x, test_y):
        """ Reads in train validate test data for tuning """

        self.train_x = train_x
        print("Read in Train X data")

        self.train_y = train_y
        print("Read in Train x data")

        self.val_x = val_x
        print("Read in Val X data")

        self.val_y = val_y
        print("Read in Val y data")

        self.test_x = test_x
        print("Read in Test X data")

        self.test_y = test_y
        print("Read in Test y data")



    def read_in_model(self, model, type):
        """ Reads in underlying model object for tuning, and also read in what type of model it is """

        assert type == 'Classification' or type == 'Regression' # check

        # record
        self.model = model
        self.clf_type = type 

        print(f'Successfully read in model {self.model}, which is a {self.clf_type} model')



    def set_hyperparameters(self, parameter_choices):
        """ Input hyperparameter choices """

        self.parameter_choices = parameter_choices

        self.hyperparameters = list(parameter_choices.keys())

        # automatically calculate how many different values in each hyperparameter
        self.n_items = [len(parameter_choices[key]) for key in self.hyperparameters]

        # automatically calculate all combinations and setup checked and result arrays and tuning result dataframe
        self._get_combinations()
        self._get_checked_and_result_array()
        self._setup_tuning_result_df()

        print("Successfully recorded hyperparameter choices")



    def set_tuning_result_saving_address(self, address):
        """ Read in where to save tuning object """

        self.tuning_result_saving_address = address
        print('Successfully set tuning output address')


    
    def _set_object_saving_address(self, address):
        """ Read in where to save the JiXi object """

        self.object_saving_address = address
        print('Successfully set object output address')



    def _get_combinations(self):
        """ Helper to calculate all combinations """

        ##ALGORITHM

        # recursively append values to get every combination in ordinal/numerical form
        self.combos = [[]]
        for i in range(len(self.n_items)):

            tmp = copy.deepcopy(self.combos)
            self.combos = list()

            for x in tmp:

                for k in range(self.n_items[i]):
                    y = copy.deepcopy(x)
                    
                    y.append(k)

                    self.combos.append(y)



    def _get_checked_and_result_array(self):
        """ Helper to set up checked and result array """

        self.checked = np.zeros(shape=self.n_items)
        self.result = np.zeros(shape=self.n_items)



    def _setup_tuning_result_df(self):
        """ Helper to set up tuning result dataframe """

        tune_result_columns = copy.deepcopy(self.hyperparameters)

        # Different set of metric columns for different types of models
        if self.clf_type == 'Classification':
            tune_result_columns.extend(self.classification_extra_output_columns)
        elif self.clf_type == 'Regression':
            tune_result_columns.extend(self.regression_extra_output_columns)

        self.tuning_result = pd.DataFrame({col:list() for col in tune_result_columns})


    
    def change_tuning_style(self, type, seed = None, outer_most_layer = 2, randomise = True): 
        # Function which determines how to order the combinations for tuning

        if not self.combos:
            print("Missing hyperparameter choices, please run .set_hyperparameters() first")
            return

        self.combos.sort() # to ensure functionality of seed, always sort first

        if type == 'a': # Sorted order (nested loops)
            # sorting operation conducted previously
            print('Changed tuning order to sorted')
        
        elif type == 'b': # Random order
            
            if seed:
                random.seed(seed)
            else:
                random.seed(self._seed)
            
            random.shuffle(self.combos)
            print('Changed tuning_order to randomised')
        
        elif type == 'c': # Layer by Layer 
            self._change_tuning_style_c(outer_most_layer, randomise, seed)
            if randomise:
                print(f'Changed tuning order to "Layer by Layer": {self.outmost_layer} Layers, randomised')
            else:
                print(f'Changed tuning order to "Layer by Layer": {self.outmost_layer} Layers, not randomised')

        elif type == 'd': # Diagonal + Horizontal first, before conducting layer by layer
            self._change_tuning_style_d()
            print(f'Changed tuning order to Diag-Hor -> "Layer by Layer": {self.outmost_layer} Layers, randomised')



    def _get_core(self):
        """ Helper to calculate core """
        self._core = [int(i/2) for i in self.n_items]



    def _get_relative_combos(self):
        """ Helper to calculate relative coordinates of combinations""" 
        self._relative_combos = [[combo[j] - self._core[j] for j in range(len(self.n_items))] for combo in self.combos]



    ### TYPE C
    def _get_both_combos(self):
        """ Helper to put (combos, relative combos) together into a tuple """
        self._get_relative_combos()
        self._both_combos = [[self.combos[i], self._relative_combos[i]] for i in range(len(self.combos))]



    def _get_layer_by_layer(self):
        """ Helper to get Layer by Layer order """

        retain = copy.deepcopy(self._both_combos)
        self._dealt_with = list()

        # starting with the outmost layer, ending with -1 because of the >
        for i in range(self.outmost_layer, -2, -1):
            tmp_retain = list()
            tmp_dealt_with = list()
            
            for item in retain:

                trigger = 1
                for j in item[1]:
                    if abs(j) > i:
                        tmp_dealt_with.append(item[0])
                        trigger = 0
                        break
                
                if trigger:
                    tmp_retain.append(item)

            retain = tmp_retain
            self._dealt_with.append(tmp_dealt_with)



    def _get_c_combos(self):
        """ Helper to get the combinations into Layer by Layer order """

        self.combos = list()
        # working with dealt_with backwards because we want the innermost layers first
        for i in range(len(self._dealt_with)-1, -1, -1):
            self.combos.extend(self._dealt_with[i])
            


    def _change_tuning_style_c(self, outmost_layer, randomise, seed):
        """ Helper to run all type-c helpers to get combinations into Layer by Layer order """

        if randomise:
            if seed:
                random.seed(seed)
            else:
                random.seed(self._seed)
        
        random.shuffle(self.combos)

        self.outmost_layer = outmost_layer
        self._get_core()
        self._get_both_combos()
        self._get_layer_by_layer()
        self._get_c_combos()



    ### TYPE D    
    def _change_tuning_style_d(self):
        """ Helper to all type-d helpers to get combinations into Layer by Layer order """

        self._change_tuning_style_c(outmost_layer= max(self.n_items), randomise = True, seed = self._seed)

        self._get_hor_combos()
        self._get_diag_combos()

        self._get_d_combos()



    def _get_hor_combos(self):
        """ Helper to get all combinations that lie on horizontal line from core """
        self._hor_combos = list()
        for i in range(len(self.n_items)):
            for j in range(self.n_items[i]):
                tmp = copy.deepcopy(self._core)
                tmp[i] = j
                self._hor_combos.append(tmp)



    def _get_pos_neg_combos(self):
        """ Helper to get all combinations of -1 and 1 """

        ##ALGORITHM
        self._pos_neg_combos = [[]]
        for i in range(len(self.n_items)):

            tmp = copy.deepcopy(self._pos_neg_combos)
            self._pos_neg_combos = list()

            for x in tmp:

                for k in (-1, 1):
                    y = copy.deepcopy(x)
                    
                    y.append(k)

                    self._pos_neg_combos.append(y)



    def _get_abs_max(self):
        """ Helper to get maximum absolute value of the relative combos """

        max_pos = max([self.n_items[i] - self._core[i] for i in range(len(self.n_items))])
        min_neg = min([0-self._core[i] for i in range(len(self.n_items))])

        self._abs_max = max((max_pos, abs(min_neg)))



    def _get_diag_combos(self):
        """ Helper to get all combinations that lie on diagonal line from core """

        # Implementation idea: first get all the diagonal combos (even those that go outside the field-space) 
        # by using all combinations of (-1, 1) multipled by each value from 1 to _abs_max, before eliminating combos that go
        # outside the field-space
        self._get_pos_neg_combos()
        self._get_abs_max()

        diag_rel_combos = list()
        for i in range(self._abs_max):
            diag_rel_combos.extend([[(i+1)*pos_neg_combo[j] for j in range(len(self.n_items))] for pos_neg_combo in self._pos_neg_combos])
        
        tmp_diag_combos = [[combo[j] + self._core[j] for j in range(len(self.n_items))] for combo in diag_rel_combos]

        self._diag_combos = list()
        
        for combo in tmp_diag_combos:
            trigger = 1
            for i in range(len(combo)):
                if combo[i] < 0 or combo[i] >= self.n_items[i]: # if outside field space then eliminate
                    trigger = 0
                    break
            
            if trigger:
                self._diag_combos.append(combo)



    def _get_d_combos(self):
        """ Helper to run all type-c helpers to get combinations into Diag-Hor -> Layer by Layer order """

        self._new_combos = list()

        self._new_combos.append(self._core)

        # put in diagonal first to get more variety
        for combo in self._diag_combos:
            if combo not in self._new_combos:
                self._new_combos.append(combo)

        for combo in self._hor_combos:
            if combo not in self._new_combos:
                self._new_combos.append(combo)

        # put in rest of the combos - already sorted in layer by layer order
        for combo in self.combos:
            if combo not in self._new_combos:
                self._new_combos.append(combo)
        
        self.combos = self._new_combos


        
    def tune(self): #TODO
        """ Begin tuning """

        if self.train_x is None or self.train_y is None or self.val_x is None or self.val_y is None or self.test_x is None or self.test_y is None:
            print(" Missing one of the datasets, please run .read_in_data() ")
            return

        if self.model is None:
            print(" Missing model, please run .read_in_model() ")
            return
        
        if self.combos is None:
            print("Missing hyperparameter choices, please run .set_hyperparameters() first")
            return

        if self.tuning_result_saving_address is None:
            print("Missing tuning result csv saving address, please run ._save_tuning_result() first")


        self._up_to = 0     # reset

        for combo in self.combos:
            
            self._up_to += 1

            if not self.checked[tuple(combo)]:

                self._train_and_test_combo(combo)
            
            else:
                print(f'Already Trained and Tested combination {self._up_to}')
            


    def _train_and_test_combo(self, combo):
        """ Helper to train and test each combination as part of tune() """

        combo = tuple(combo)
        
        params = {self.hyperparameters[i]:self.parameter_choices[self.hyperparameters[i]][combo[i]] for i in range(len(self.hyperparameters))}

        # initialise object
        clf = self.model(**params)

        # get time and fit
        start = time.time()
        clf.fit(self.train_x, self.train_y)
        end = time.time()

        # get predicted labels/values for three datasets
        train_pred = clf.predict(self.train_x)
        val_pred = clf.predict(self.val_x)
        test_pred = clf.predict(self.test_x)

        # get scores and time used
        time_used = end-start

        # build output dictionary and save result
        df_building_dict = params

        if self.clf_type == 'Regression':
            train_score = r2_score(self.train_y, train_pred)
            val_score = r2_score(self.val_y, val_pred)
            test_score = r2_score(self.test_y, test_pred)

            train_rmse = np.sqrt(mean_squared_error(self.train_y, train_pred))
            val_rmse = np.sqrt(mean_squared_error(self.val_y, val_pred))
            test_rmse = np.sqrt(mean_squared_error(self.test_y, test_pred))

            train_mape = mean_absolute_percentage_error(self.train_y, train_pred)
            val_mape = mean_absolute_percentage_error(self.val_y, val_pred)
            test_mape = mean_absolute_percentage_error(self.test_y, test_pred)

            df_building_dict['Train r2'] = [np.round(train_score, 4)]
            df_building_dict['Val r2'] = [np.round(val_score, 4)]
            df_building_dict['Test r2'] = [np.round(test_score, 4)]
            df_building_dict['Train RMSE'] = [np.round(train_rmse, 4)]
            df_building_dict['Val RMSE'] = [np.round(val_rmse, 4)]
            df_building_dict['Test RMSE'] = [np.round(test_rmse, 4)]
            df_building_dict['Train MAPE'] = [np.round(train_mape, 4)]
            df_building_dict['Val MAPE'] = [np.round(val_mape, 4)]
            df_building_dict['Test MAPE'] = [np.round(test_mape, 4)]
            df_building_dict['Time'] = [np.round(time_used, 2)]

        
        elif self.clf_type == 'Classification':
            train_score = accuracy_score(self.train_y, train_pred)
            val_score = clf.score(self.val_y, val_pred)
            test_score = clf.score(self.test_y, test_pred)

            train_bal_accu = balanced_accuracy_score(self.train_y, train_pred)
            val_bal_accu = balanced_accuracy_score(self.val_y, val_pred)
            test_bal_accu = balanced_accuracy_score(self.test_y, test_pred)

            train_f1 = f1_score(self.train_y, train_pred, average='weighted')
            val_f1 = f1_score(self.val_y, val_pred, average='weighted')
            test_f1 = f1_score(self.test_y, test_pred, average='weighted')

            train_precision = precision_score(self.train_y, train_pred, average='weighted')
            val_precision = precision_score(self.val_y, val_pred, average='weighted')
            test_precision = precision_score(self.test_y, test_pred, average='weighted')
        
            train_recall = recall_score(self.train_y, train_pred, average='weighted')
            val_recall = recall_score(self.val_y, val_pred, average='weighted')
            test_recall = recall_score(self.test_y, test_pred, average='weighted')

            df_building_dict['Train accu'] = [np.round(train_score, 4)]
            df_building_dict['Val accu'] = [np.round(val_score, 4)]
            df_building_dict['Test accu'] = [np.round(test_score, 4)]
            df_building_dict['Train balanced_accuracy'] = [np.round(train_bal_accu, 4)]
            df_building_dict['Val balanced_accuracy'] = [np.round(val_bal_accu, 4)]
            df_building_dict['Test balanced_accuracy'] = [np.round(test_bal_accu, 4)]
            df_building_dict['Train f1'] = [np.round(train_f1, 4)]
            df_building_dict['Val f1'] = [np.round(val_f1, 4)]
            df_building_dict['Test f1'] = [np.round(test_f1, 4)]
            df_building_dict['Train precision'] = [np.round(train_precision, 4)]
            df_building_dict['Val precision'] = [np.round(val_precision, 4)]
            df_building_dict['Test precision'] = [np.round(test_precision, 4)]
            df_building_dict['Train recall'] = [np.round(train_recall, 4)]
            df_building_dict['Val recall'] = [np.round(val_recall, 4)]
            df_building_dict['Test recall'] = [np.round(test_recall, 4)]
            df_building_dict['Time'] = [np.round(time_used, 2)]

        tmp = pd.DataFrame(df_building_dict)

        self.tuning_result = self.tuning_result.append(tmp)
        self._save_tuning_result()

        # update best score stats
        if val_score > self.best_score: 
            self.best_score = val_score
            self.best_clf = clf
            self.best_combo = combo

        # update internal governing DataFrames
        self.checked[combo] = 1
        self.result[combo] = val_score


        print(f'''Trained and Tested combination {self._up_to}, taking {np.round(time_used, 2)} seconds
        Current best combo: {self.best_combo} with val score {self.best_score}''')



    def _save_tuning_result(self):
        """ Helper to export tuning result csv """

        self.tuning_result.to_csv(self.tuning_result_saving_address, index=False)

    

    def read_in_tuning_result_df(self, address): 
        """ Read in tuning result csv and read data into checked and result arrays """

        if self.parameter_choices is None:
            print("Missing parameter_choices to build parameter_value_map_index, please run set_hyperparameters() first")

        if self.clf_type is None:
            print('Missing clf_type. Please run .read_in_model() first.')

        self.tuning_result = pd.read_csv(address)
        print(f"Successfully read in tuning result of {len(self.tuning_result)} rows")

        self._create_parameter_value_map_index()

        # read DataFrame data into internal governing DataFrames of JiXi
        for row in self.tuning_result.iterrows():
    
            combo = tuple([self.parameter_value_map_index[hyperparam][row[1][hyperparam]] for hyperparam in self.hyperparameters])
            
            self.checked[combo] = 1
            
            if self.clf_type == 'Regression':
                self.result[combo] = row[1]['Val r2']
            elif self.clf_type == 'Classification':
                self.result[combo] = row[1]['Val accu']
        
            # update best score stats
            if self.result[combo] > self.best_score: 
                self.best_score = self.result[combo]
                self.best_clf = None
                print(f"As new Best Combo {combo} is read in, best_clf is set to None")
                self.best_combo = combo


    
    def _create_parameter_value_map_index(self):
        """ Helper to create parameter-value index map """

        self.parameter_value_map_index = dict()
        for key in self.parameter_choices.keys():
            tmp = dict()
            for i in range(len(self.parameter_choices[key])):
                tmp[self.parameter_choices[key][i]] = i
            self.parameter_value_map_index[key] = tmp
    


    def export_jixi(self, address):
        """ Export jixi object """

        self._set_object_saving_address(address)

        # copy object and set big objects to None
        object_save = copy.deepcopy(self)
        
        object_save.train_x = None
        object_save.train_y = None
        object_save.val_x = None
        object_save.val_y = None
        object_save.test_x = None
        object_save.test_y = None
        object_save._up_to = 0

        # Export
        with open(f'{self.object_saving_address}.pickle', 'wb') as f:
            pickle.dump(object_save, f)

        print(f'Successfully exported JiXi object as {self.object_saving_address}')



    def view_best_combo_and_score(self):
        """ View best combination and its validation score """
        
        print(f'(Current) Best combo: {self.best_combo} with val score {self.best_score}')

# %%
jixi = JiXi()
# Out:
# JiXi Initialised

# %% [markdown]
# Read in and Prepare Data

# %%
train_data = pd.read_csv('../data/curated/modelling/RS_Train_3.csv')
val_data = pd.read_csv('../data/curated/modelling/RS_Validate_3.csv')
test_data = pd.read_csv('../data/curated/modelling/RS_Test_3.csv')

# %%
train_x = train_data.drop(['3'], axis=1)
train_y = train_data['3']
val_x = val_data.drop(['3'], axis=1)
val_y = val_data['3']
test_x = test_data.drop(['3'], axis=1)
test_y = test_data['3']

# %%
jixi.read_in_data(train_x, train_y, val_x, val_y, test_x, test_y)
# Out:
# Read in Train X data
# Read in Train x data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data

# %% [markdown]
# Set parameters

# %%
# from sklearn.ensemble import RandomForestRegressor as RFR
# from sklearn.neighbors import  KNeighborsRegressor as KNR
import xgboost

# %%
# rfr = RFR
# knr = KNR
xgb = xgboost.XGBRegressor

# %%
jixi.read_in_model(xgb, 'Regression')
# Out:
# Successfully read in model <class 'xgboost.sklearn.XGBRegressor'>, which is a Regression model

# %%
# parameter_choices = {
#     'n_estimators': (50, 100),
#     'max_depth': (5, 10, 25, 50, 100) ,   
#     'random_state': (19421220,),
#     'ccp_alpha': (0, 0.0001, 0.01, 1, 100, 10000),
#     'max_samples': (0.5, 0.75),
#     'max_features': (0.5, 0.75)
# }

# parameter_choices = {
#     'n_neighbors': tuple(range(5, 201, 5)),
#     'weights': ('uniform', 'distance')
# }

parameter_choices = {
    'gamma': (0, 0.0001, 0.01, 1, 100),
    'subsample': (0.25, 0.5, 0.75),
    'colsample_bytree': (0.25, 0.5, 0.75),
    'max_depth': (5, 10, 25, 50, 100),
    'eta': (0.15, 0.3, 0.45, 0.6, 0.75, 0.9)

}

# %%
jixi.set_hyperparameters(parameter_choices)
# Out:
# Successfully recorded parameter choices

# %%
jixi.change_tuning_style('d')
# Out:
# Changed tuning order to diag-hor -> "Layer by Layer": 6 Layers, randomised

# %%
# import ZhongShan
# zhongshan = ZhongShan

# zhongshan.setup_directory('../models/tuning')

# %%
# jixi.read_in_tuning_result_df('../models/tuning/RS_knr_3.csv')

# %%
jixi.set_tuning_result_saving_address('../models/tuning/RS_xgb_3.csv')
# Out:
# Successfully set tuning output address

# %%
jixi.tune()
# Out:
# Trained and Tested combination 1, taking 19.88 seconds
#         Current best combo: None with val score 0
# Trained and Tested combination 2, taking 1.57 seconds
#         Current best combo: None with val score 0
# Trained and Tested combination 3, taking 17.2 seconds
#         Current best combo: None with val score 0
# Trained and Tested combination 4, taking 2.57 seconds
#         Current best combo: None with val score 0
# Trained and Tested combination 5, taking 15.4 seconds
#         Current best combo: None with val score 0
# Trained and Tested combination 6, taking 1.36 seconds
#         Current best combo: None with val score 0
# Trained and Tested combination 7, taking 15.43 seconds
#         Current best combo: None with val score 0
# Trained and Tested combination 8, taking 3.28 seconds
#         Current best combo: None with val score 0
# Trained and Tested combination 9, taking 1.76 seconds
#         Current best combo: None with val score 0
# Trained and Tested combination 10, taking 18.12 seconds
#         Current best combo: None with val score 0
# Trained and Tested combination 11, taking 12.33 seconds
#         Current best combo: None with val score 0
# Trained and Tested combination 12, taking 4.11 seconds
#         Current best combo: None with val score 0
# Trained and Tested combination 13, taking 30.14 seconds
#         Current best combo: None with val score 0
# Trained and Tested combination 14, taking 14.25 seconds
#         Current best combo: (3, 2, 1, 3, 0) with val score 0.050666316584807025
# Trained and Tested combination 15, taking 1.17 seconds
#         Current best combo: (3, 2, 1, 3, 0) with val score 0.050666316584807025
# Trained and Tested combination 16, taking 6.21 seconds
#         Current best combo: (3, 2, 1, 3, 0) with val score 0.050666316584807025
# Trained and Tested combination 17, taking 10.59 seconds
#         Current best combo: (3, 2, 1, 3, 0) with val score 0.050666316584807025
# Trained and Tested combination 18, taking 1.47 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 19, taking 6.92 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 20, taking 5.76 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 21, taking 1.79 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 22, taking 12.69 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 23, taking 3.24 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 24, taking 1.05 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 25, taking 1.56 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 26, taking 8.63 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 27, taking 2.52 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 28, taking 3.69 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 29, taking 1.59 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 30, taking 22.2 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 31, taking 8.57 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 32, taking 4.33 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 33, taking 0.87 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 34, taking 22.33 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 35, taking 1.04 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 36, taking 3.77 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 37, taking 9.49 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 38, taking 0.98 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 39, taking 27.92 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 40, taking 4.05 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 41, taking 3.32 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 42, taking 3.59 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 43, taking 2.14 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 44, taking 14.06 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 45, taking 6.02 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 46, taking 2.89 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 47, taking 7.25 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 48, taking 16.23 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 49, taking 7.82 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 50, taking 2.26 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 51, taking 2.56 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 52, taking 1.35 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 53, taking 3.48 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 54, taking 18.28 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 55, taking 1.1 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 56, taking 0.86 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 57, taking 3.55 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 58, taking 15.67 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 59, taking 2.64 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 60, taking 20.95 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 61, taking 1.36 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 62, taking 1.02 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 63, taking 0.81 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 64, taking 4.95 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 65, taking 2.45 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 66, taking 2.14 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 67, taking 26.13 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 68, taking 10.51 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 69, taking 5.29 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 70, taking 3.18 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 71, taking 18.64 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 72, taking 2.28 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 73, taking 0.76 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 74, taking 8.48 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 75, taking 3.85 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 76, taking 0.95 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 77, taking 0.8 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 78, taking 3.06 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 79, taking 8.24 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 80, taking 11.61 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 81, taking 7.16 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 82, taking 16.27 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 83, taking 1.27 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 84, taking 4.64 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 85, taking 2.6 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 86, taking 6.55 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 87, taking 1.6 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 88, taking 8.45 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 89, taking 1.85 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 90, taking 8.68 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 91, taking 2.62 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 92, taking 17.11 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 93, taking 19.86 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 94, taking 6.11 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 95, taking 0.99 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 96, taking 14.83 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 97, taking 15.68 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 98, taking 3.85 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 99, taking 3.25 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 100, taking 5.53 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 101, taking 9.1 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 102, taking 1.02 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 103, taking 3.71 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 104, taking 3.4 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 105, taking 5.87 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 106, taking 3.71 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 107, taking 3.55 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 108, taking 3.24 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 109, taking 5.23 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 110, taking 1.74 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 111, taking 8.75 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 112, taking 15.48 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 113, taking 2.51 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 114, taking 4.14 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 115, taking 3.7 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 116, taking 3.7 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 117, taking 2.9 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 118, taking 1.16 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 119, taking 5.69 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 120, taking 6.68 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 121, taking 19.47 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 122, taking 16.98 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 123, taking 12.34 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 124, taking 3.77 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 125, taking 5.86 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 126, taking 3.6 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 127, taking 18.68 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 128, taking 3.15 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 129, taking 4.2 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 130, taking 20.4 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 131, taking 3.62 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 132, taking 6.35 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 133, taking 17.56 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 134, taking 20.75 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 135, taking 16.95 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 136, taking 16.75 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 137, taking 3.43 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 138, taking 1.0 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 139, taking 7.05 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 140, taking 4.21 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 141, taking 4.72 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 142, taking 0.99 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 143, taking 10.97 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 144, taking 10.94 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 145, taking 7.98 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 146, taking 15.85 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 147, taking 10.2 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 148, taking 13.56 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 149, taking 18.27 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 150, taking 13.21 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 151, taking 1.2 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 152, taking 3.47 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 153, taking 1.2 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 154, taking 3.16 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 155, taking 1.94 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 156, taking 12.49 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 157, taking 6.54 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 158, taking 2.96 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 159, taking 6.32 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 160, taking 3.44 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 161, taking 11.6 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 162, taking 1.85 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 163, taking 10.86 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 164, taking 11.7 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 165, taking 9.63 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 166, taking 8.18 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 167, taking 2.67 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 168, taking 1.85 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 169, taking 1.04 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 170, taking 13.44 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 171, taking 3.03 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 172, taking 2.96 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 173, taking 5.37 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 174, taking 1.07 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 175, taking 1.92 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 176, taking 2.73 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 177, taking 2.7 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 178, taking 3.45 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 179, taking 3.47 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 180, taking 5.81 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 181, taking 1.35 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 182, taking 5.68 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 183, taking 5.2 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 184, taking 5.17 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 185, taking 1.34 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 186, taking 1.59 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 187, taking 11.57 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 188, taking 7.54 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 189, taking 8.63 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 190, taking 2.89 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 191, taking 0.94 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 192, taking 9.07 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 193, taking 0.79 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 194, taking 2.03 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 195, taking 5.21 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 196, taking 21.14 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 197, taking 4.64 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 198, taking 3.67 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 199, taking 3.57 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 200, taking 4.75 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 201, taking 11.77 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 202, taking 8.09 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 203, taking 5.41 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 204, taking 3.47 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 205, taking 0.79 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 206, taking 7.45 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 207, taking 8.62 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 208, taking 0.93 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 209, taking 3.35 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 210, taking 1.57 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 211, taking 6.24 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 212, taking 11.98 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 213, taking 1.35 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 214, taking 8.9 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 215, taking 6.4 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 216, taking 6.77 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 217, taking 0.93 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 218, taking 2.92 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 219, taking 3.04 seconds
#         Current best combo: (3, 2, 1, 0, 0) with val score 0.08711175773125135
# Trained and Tested combination 220, taking 1.5 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 221, taking 9.46 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 222, taking 0.78 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 223, taking 1.34 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 224, taking 14.65 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 225, taking 3.7 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 226, taking 4.52 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 227, taking 1.51 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 228, taking 19.43 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 229, taking 3.3 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 230, taking 3.28 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 231, taking 2.95 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 232, taking 8.89 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 233, taking 2.65 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 234, taking 5.04 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 235, taking 21.26 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 236, taking 8.96 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 237, taking 2.87 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 238, taking 2.93 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 239, taking 1.32 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 240, taking 5.41 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 241, taking 10.18 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 242, taking 1.8 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 243, taking 6.71 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 244, taking 2.53 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 245, taking 6.94 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 246, taking 2.47 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 247, taking 8.55 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 248, taking 11.95 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 249, taking 1.14 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 250, taking 1.63 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 251, taking 23.24 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 252, taking 10.07 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 253, taking 2.9 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 254, taking 10.35 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 255, taking 12.24 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 256, taking 8.87 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 257, taking 17.52 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 258, taking 10.23 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 259, taking 3.52 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 260, taking 11.56 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 261, taking 16.86 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 262, taking 2.31 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 263, taking 5.87 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 264, taking 3.09 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 265, taking 7.51 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 266, taking 13.25 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 267, taking 7.2 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 268, taking 0.94 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 269, taking 3.07 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 270, taking 11.77 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 271, taking 1.36 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 272, taking 15.04 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 273, taking 9.74 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 274, taking 1.97 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 275, taking 4.54 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 276, taking 6.17 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 277, taking 4.29 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 278, taking 14.93 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 279, taking 1.59 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 280, taking 3.73 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 281, taking 6.67 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 282, taking 5.71 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 283, taking 1.72 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 284, taking 1.76 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 285, taking 1.42 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 286, taking 27.09 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 287, taking 3.76 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 288, taking 2.06 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 289, taking 1.41 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 290, taking 2.66 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 291, taking 8.83 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 292, taking 6.41 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 293, taking 20.94 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 294, taking 3.69 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 295, taking 3.89 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 296, taking 3.21 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 297, taking 1.62 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 298, taking 12.9 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 299, taking 9.51 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 300, taking 4.01 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 301, taking 29.86 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 302, taking 1.99 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 303, taking 3.61 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 304, taking 2.32 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 305, taking 2.02 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 306, taking 9.67 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 307, taking 3.07 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 308, taking 1.6 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 309, taking 18.05 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 310, taking 22.98 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 311, taking 5.68 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 312, taking 1.88 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 313, taking 2.17 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 314, taking 4.33 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 315, taking 17.49 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 316, taking 3.24 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 317, taking 6.09 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 318, taking 1.38 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 319, taking 7.86 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 320, taking 5.31 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 321, taking 3.48 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 322, taking 1.6 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 323, taking 5.13 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 324, taking 18.58 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 325, taking 1.6 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 326, taking 4.45 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 327, taking 1.84 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 328, taking 5.26 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 329, taking 1.57 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 330, taking 1.08 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 331, taking 3.64 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 332, taking 6.16 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 333, taking 2.83 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 334, taking 19.01 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 335, taking 8.37 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 336, taking 11.5 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 337, taking 1.54 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 338, taking 6.24 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 339, taking 9.46 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 340, taking 2.31 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 341, taking 2.63 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 342, taking 6.54 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 343, taking 6.59 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 344, taking 1.35 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 345, taking 3.5 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 346, taking 21.44 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 347, taking 1.36 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 348, taking 1.9 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 349, taking 3.07 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 350, taking 20.71 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 351, taking 9.82 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 352, taking 1.56 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 353, taking 10.25 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 354, taking 2.41 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 355, taking 22.8 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 356, taking 11.9 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 357, taking 4.74 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 358, taking 13.98 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 359, taking 2.55 seconds
# ...
# Trained and Tested combination 1234, taking 21.87 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1235, taking 4.57 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1236, taking 6.08 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1237, taking 1.04 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1238, taking 17.06 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1239, taking 11.54 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1240, taking 1.05 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1241, taking 1.35 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1242, taking 8.54 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1243, taking 18.9 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1244, taking 1.56 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1245, taking 17.79 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1246, taking 11.58 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1247, taking 3.57 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1248, taking 1.56 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1249, taking 14.8 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1250, taking 1.18 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1251, taking 16.49 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1252, taking 3.6 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1253, taking 6.63 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1254, taking 1.61 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1255, taking 1.51 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1256, taking 3.67 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1257, taking 7.8 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1258, taking 1.38 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1259, taking 6.2 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1260, taking 4.54 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1261, taking 0.94 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1262, taking 19.12 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1263, taking 6.41 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1264, taking 8.91 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1265, taking 18.04 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1266, taking 10.52 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1267, taking 3.68 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1268, taking 8.24 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1269, taking 13.66 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1270, taking 6.74 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1271, taking 1.95 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1272, taking 0.81 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1273, taking 2.0 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1274, taking 11.82 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1275, taking 1.07 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1276, taking 3.82 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1277, taking 7.87 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1278, taking 1.5 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1279, taking 5.06 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1280, taking 12.25 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1281, taking 1.53 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1282, taking 1.58 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1283, taking 593.81 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1284, taking 20.7 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1285, taking 6.54 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1286, taking 0.93 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1287, taking 5.36 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1288, taking 2.34 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1289, taking 0.95 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1290, taking 13.39 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1291, taking 24.85 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1292, taking 19.76 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1293, taking 5.84 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1294, taking 3.44 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1295, taking 13.77 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1296, taking 0.99 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1297, taking 6.18 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1298, taking 1.91 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1299, taking 7.52 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1300, taking 1.06 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1301, taking 2.88 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1302, taking 6.86 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1303, taking 0.93 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1304, taking 6.19 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1305, taking 16.59 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1306, taking 0.77 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1307, taking 1.52 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1308, taking 3.25 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1309, taking 5.44 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1310, taking 9.27 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1311, taking 8.73 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1312, taking 8.46 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1313, taking 0.79 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1314, taking 1.05 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1315, taking 3.63 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1316, taking 1.54 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1317, taking 9.81 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1318, taking 1.35 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1319, taking 0.94 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1320, taking 6.7 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1321, taking 6.11 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1322, taking 1.33 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1323, taking 2.36 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1324, taking 2.78 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1325, taking 5.93 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1326, taking 1.17 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1327, taking 5.82 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1328, taking 18.32 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1329, taking 12.36 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1330, taking 1.91 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1331, taking 1.49 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1332, taking 3.76 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1333, taking 2.97 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1334, taking 6.51 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1335, taking 1.91 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1336, taking 2.36 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1337, taking 18.92 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1338, taking 8.32 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1339, taking 4.62 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1340, taking 2.29 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1341, taking 8.64 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1342, taking 2.95 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1343, taking 1.58 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1344, taking 0.94 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1345, taking 3.47 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1346, taking 16.32 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1347, taking 8.15 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1348, taking 0.96 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1349, taking 1.31 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294
# Trained and Tested combination 1350, taking 1.13 seconds
#         Current best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294

# %%
jixi.view_best_combo_and_score()
# Out:
# (Current) Best combo: (3, 2, 2, 0, 0) with val score 0.09547046147666294

# %%
# jixi.export_jixi('test')

# %%
# with open('test.pickle', 'rb') as f:
#     jixi = pickle.load(f)

# %% [markdown]
# D
