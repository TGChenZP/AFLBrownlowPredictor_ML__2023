# %%
import pandas as pd
import copy
import time
import numpy as np
import random

# %%
class TaiZhou:



    def __init__(self):
        pass

        self._initialise_objects()

        print('TaiZhou Initialised')



    def _initialise_objects(self):

        self.train_x = None
        self.train_y = None
        self.val_x = None
        self.val_y = None
        self.test_x = None
        self.test_y = None
        self.tuning_result = None
        self.model = None
        self.parameter_choices = None
        self.hyperparameters = None
        self.checked = None
        self.result = None
        self.tuning_result = None
        self.tuning_result_saving_address = None
        self._up_to = 0
        self._seed = 19421221
        self.best_score = 0
        self.best_combo = None
        self.best_clf = None

        self.extra_output_columns = ['Train score', 'Val score', 'Test score', 'Time']

        

    def read_in_data(self, train_x, train_y, val_x, val_y, test_x, test_y):

        self.train_x = train_x
        print("Read in Train X data")

        self.train_y = train_y
        print("Read in Train x data")

        self.val_x = val_x
        print("Read in Val X data")

        self.val_y = val_y
        print("Read in Val y data")

        self.test_x = test_x
        print("Read in Test X data")

        self.test_y = test_y
        print("Read in Test y data")



    def read_in_model(self, model):

        self.model = model

        print(f'Successfully read in model {self.model}')



    def set_parameters(self, parameter_choices):
        
        self.parameter_choices = parameter_choices

        self.hyperparameters = list(parameter_choices.keys())

        self.n_items = [len(parameter_choices[key]) for key in self.hyperparameters]

        self._get_combinations()
        self._get_checked_and_result_array()
        self._setup_tuning_result_df()

        print("Successfully recorded parameter choices")


    def set_address(self, address):
        
        self.tuning_result_saving_address = address
        print('Successfully set tuning output address')



    def _get_combinations(self):
        
        self.combos = [[]]
        for i in range(len(self.n_items)):

            tmp = copy.deepcopy(self.combos)
            self.combos = list()

            for x in tmp:

                for k in range(self.n_items[i]):
                    y = copy.deepcopy(x)
                    
                    y.append(k)

                    self.combos.append(y)



    def _get_checked_and_result_array(self):

        self.checked = np.zeros(shape=self.n_items)
        self.result = np.zeros(shape=self.n_items)



    def _setup_tuning_result_df(self):

        tune_result_columns = copy.deepcopy(self.hyperparameters)
        tune_result_columns.extend(self.extra_output_columns)

        self.tuning_result = pd.DataFrame({col:list() for col in tune_result_columns})


    
    def change_tuning_style(self, type, seed = None): #TODO
        
        if type == 'a':
            self.combos.sort()
            print('Changed tuning order to sorted')
        
        elif type == 'b':
            if seed:
                random.seed(seed)
            else:
                random.seed(self._seed)
            
            random.shuffle(self.combos)
            print('Changed tuning_order to randomised')
        
        elif type == 'c':
            pass

        elif type == 'd':
            pass


    
    def tune(self): #TODO
        
        for combo in self.combos:
            
            self._up_to += 1

            if not self.checked[tuple(combo)]:

                self._train_and_test_combo(combo)
            


    def _train_and_test_combo(self, combo):
        
        params = {self.hyperparameters[i]:self.parameter_choices[self.hyperparameters[i]][combo[i]] for i in range(len(self.hyperparameters))}

        # initialise object
        clf = self.model(**params)

        # get time and fit
        start = time.time()
        clf.fit(self.train_x, self.train_y)
        end = time.time()

        # get scores and time used
        train_score = clf.score(self.train_x, self.train_y)
        val_score = clf.score(self.val_x, self.val_y)
        test_score = clf.score(self.test_x, self.test_y)
        time_used = end-start

        # build output dictionary and save result
        df_building_dict = params
        df_building_dict['Train score'] = [np.round(train_score, 4)]
        df_building_dict['Val score'] = [np.round(val_score, 4)]
        df_building_dict['Test score'] = [np.round(test_score, 4)]
        df_building_dict['Time'] = [np.round(time_used, 2)]

        tmp = pd.DataFrame(df_building_dict)

        self.tuning_result = self.tuning_result.append(tmp)
        self._save_tuning_result()

        # update best score stats
        if val_score > self.best_score: 
            self.best_score = val_score
            self.best_clf = clf
            self.best_combo = combo

        # update underlying governing DataFrames
        combo = tuple(combo)

        self.checked[combo] = 1
        self.result[combo] = val_score


        print(f'Trained and tested combination {self._up_to}, taking {np.round(time_used, 2)} seconds\n')



    def _save_tuning_result(self):

        self.tuning_result.to_csv(self.tuning_result_saving_address, index=False)

    

    def read_in_checked_result(): #???
        pass

# %%
taizhou = TaiZhou()
# Out:
# TaiZhou Initialised

# %% [markdown]
# Read in and Prepare Data

# %%
train_data = pd.read_csv('../data/curated/modelling/Train_1.csv')
val_data = pd.read_csv('../data/curated/modelling/Validate_1.csv')
test_data = pd.read_csv('../data/curated/modelling/Test_1.csv')

# %%
train_x = train_data.drop(['1'], axis=1)
train_y = train_data['1']
val_x = val_data.drop(['1'], axis=1)
val_y = val_data['1']
test_x = test_data.drop(['1'], axis=1)
test_y = test_data['1']

# %%
taizhou.read_in_data(train_x, train_y, val_x, val_y, test_x, test_y)
# Out:
# Read in Train X data
# Read in Train x data
# Read in Val X data
# Read in Val y data
# Read in Test X data
# Read in Test y data

# %% [markdown]
# Set parameters

# %%
from sklearn.ensemble import RandomForestRegressor as RFR

# %%
rfr = RFR

# %%
taizhou.read_in_model(rfr)
# Out:
# Successfully read in model <class 'sklearn.ensemble._forest.RandomForestRegressor'>

# %%
parameter_choices = {
    'n_estimators': (50, 100),
    'max_depth': (5, 10, 25, 50, 100) ,   
    'random_state': (19421220,),
    'ccp_alpha': (0, 0.0001, 0.01, 1, 100, 10000),
    'max_samples': (0.5, 0.75),
    'max_features': (0.5, 0.75)
}

# %%
taizhou.set_parameters(parameter_choices)
# Out:
# Successfully recorded parameter choices

# %%
taizhou.change_tuning_style('a')
# Out:
# Changed tuning order to sorted

# %%
# import ZhongShan
# zhongshan = ZhongShan

# zhongshan.setup_directory('../models/tuning')

# %%
taizhou.set_address('../models/tuning/rfr_1.csv')
# Out:
# Successfully set tuning output address

# %%
taizhou.tune()
# Out:
# Trained and tested combination 1, taking 6.45 seconds
#
# Trained and tested combination 2, taking 9.6 seconds
#
# Trained and tested combination 3, taking 8.56 seconds
#
# Trained and tested combination 4, taking 12.77 seconds
#
# Trained and tested combination 5, taking 6.43 seconds
#
# Trained and tested combination 6, taking 9.58 seconds
#
# Trained and tested combination 7, taking 8.56 seconds
#
# Trained and tested combination 8, taking 12.78 seconds
#
# Trained and tested combination 9, taking 6.43 seconds
#
# Trained and tested combination 10, taking 9.58 seconds
#
# Trained and tested combination 11, taking 8.56 seconds
#
# Trained and tested combination 12, taking 12.77 seconds
#
# Trained and tested combination 13, taking 6.43 seconds
#
# Trained and tested combination 14, taking 9.59 seconds
#
# Trained and tested combination 15, taking 8.56 seconds
#
# Trained and tested combination 16, taking 12.77 seconds
#
# Trained and tested combination 17, taking 6.43 seconds
#
# Trained and tested combination 18, taking 9.59 seconds
#
# Trained and tested combination 19, taking 8.56 seconds
#
# Trained and tested combination 20, taking 12.77 seconds
#
# Trained and tested combination 21, taking 6.43 seconds
#
# Trained and tested combination 22, taking 9.59 seconds
#
# Trained and tested combination 23, taking 8.56 seconds
#
# Trained and tested combination 24, taking 12.77 seconds
#
# Trained and tested combination 25, taking 12.38 seconds
#
# Trained and tested combination 26, taking 18.49 seconds
#
# Trained and tested combination 27, taking 16.61 seconds
#
# Trained and tested combination 28, taking 24.74 seconds
#
# Trained and tested combination 29, taking 12.39 seconds
#
# Trained and tested combination 30, taking 18.49 seconds
#
# Trained and tested combination 31, taking 16.57 seconds
#
# Trained and tested combination 32, taking 24.75 seconds
#
# Trained and tested combination 33, taking 12.39 seconds
#
# Trained and tested combination 34, taking 18.5 seconds
#
# Trained and tested combination 35, taking 16.57 seconds
#
# Trained and tested combination 36, taking 24.74 seconds
#
# Trained and tested combination 37, taking 12.4 seconds
#
# Trained and tested combination 38, taking 18.5 seconds
#
# Trained and tested combination 39, taking 16.57 seconds
#
# Trained and tested combination 40, taking 24.75 seconds
#
# Trained and tested combination 41, taking 12.38 seconds
#
# Trained and tested combination 42, taking 18.53 seconds
#
# Trained and tested combination 43, taking 16.55 seconds
#
# Trained and tested combination 44, taking 24.71 seconds
#
# Trained and tested combination 45, taking 12.37 seconds
#
# Trained and tested combination 46, taking 18.46 seconds
#
# Trained and tested combination 47, taking 16.54 seconds
#
# Trained and tested combination 48, taking 24.72 seconds
#
# Trained and tested combination 49, taking 23.19 seconds
#
# Trained and tested combination 50, taking 35.03 seconds
#
# Trained and tested combination 51, taking 32.11 seconds
#
# Trained and tested combination 52, taking 48.3 seconds
#
# Trained and tested combination 53, taking 23.2 seconds
#
# Trained and tested combination 54, taking 35.04 seconds
#
# Trained and tested combination 55, taking 32.14 seconds
#
# Trained and tested combination 56, taking 48.32 seconds
#
# Trained and tested combination 57, taking 23.21 seconds
#
# Trained and tested combination 58, taking 35.41 seconds
#
# Trained and tested combination 59, taking 32.0 seconds
#
# Trained and tested combination 60, taking 48.21 seconds
#
# Trained and tested combination 61, taking 22.99 seconds
#
# Trained and tested combination 62, taking 34.72 seconds
#
# Trained and tested combination 63, taking 31.83 seconds
#
# Trained and tested combination 64, taking 48.16 seconds
#
# Trained and tested combination 65, taking 23.08 seconds
#
# Trained and tested combination 66, taking 34.86 seconds
#
# Trained and tested combination 67, taking 31.89 seconds
#
# Trained and tested combination 68, taking 47.89 seconds
#
# Trained and tested combination 69, taking 23.11 seconds
#
# Trained and tested combination 70, taking 34.7 seconds
#
# Trained and tested combination 71, taking 31.82 seconds
#
# Trained and tested combination 72, taking 47.87 seconds
#
# Trained and tested combination 73, taking 23.19 seconds
#
# Trained and tested combination 74, taking 35.11 seconds
#
# Trained and tested combination 75, taking 32.45 seconds
#
# Trained and tested combination 76, taking 49.15 seconds
#
# Trained and tested combination 77, taking 23.2 seconds
#
# Trained and tested combination 78, taking 35.1 seconds
#
# Trained and tested combination 79, taking 32.52 seconds
#
# Trained and tested combination 80, taking 49.38 seconds
#
# Trained and tested combination 81, taking 23.37 seconds
#
# Trained and tested combination 82, taking 35.1 seconds
#
# Trained and tested combination 83, taking 32.48 seconds
#
# Trained and tested combination 84, taking 49.19 seconds
#
# Trained and tested combination 85, taking 23.21 seconds
#
# Trained and tested combination 86, taking 35.12 seconds
#
# Trained and tested combination 87, taking 32.49 seconds
#
# Trained and tested combination 88, taking 49.18 seconds
#
# Trained and tested combination 89, taking 23.21 seconds
#
# Trained and tested combination 90, taking 35.12 seconds
#
# Trained and tested combination 91, taking 32.48 seconds
#
# Trained and tested combination 92, taking 49.19 seconds
#
# Trained and tested combination 93, taking 23.21 seconds
#
# Trained and tested combination 94, taking 35.11 seconds
#
# Trained and tested combination 95, taking 32.49 seconds
#
# Trained and tested combination 96, taking 49.19 seconds
#
# Trained and tested combination 97, taking 23.19 seconds
#
# Trained and tested combination 98, taking 35.07 seconds
#
# Trained and tested combination 99, taking 32.45 seconds
#
# Trained and tested combination 100, taking 49.16 seconds
#
# Trained and tested combination 101, taking 23.21 seconds
#
# Trained and tested combination 102, taking 35.1 seconds
#
# Trained and tested combination 103, taking 32.48 seconds
#
# Trained and tested combination 104, taking 49.2 seconds
#
# Trained and tested combination 105, taking 23.2 seconds
#
# Trained and tested combination 106, taking 35.1 seconds
#
# Trained and tested combination 107, taking 51.39 seconds
#
# Trained and tested combination 108, taking 144.93 seconds
#
# Trained and tested combination 109, taking 23.57 seconds
#
# Trained and tested combination 110, taking 35.23 seconds
#
# Trained and tested combination 111, taking 32.76 seconds
#
# Trained and tested combination 112, taking 50.47 seconds
#
# Trained and tested combination 113, taking 23.49 seconds
#
# Trained and tested combination 114, taking 35.13 seconds
#
# Trained and tested combination 115, taking 32.48 seconds
#
# Trained and tested combination 116, taking 49.17 seconds
#
# Trained and tested combination 117, taking 23.22 seconds
#
# Trained and tested combination 118, taking 35.12 seconds
#
# Trained and tested combination 119, taking 32.5 seconds
#
# Trained and tested combination 120, taking 49.18 seconds
#
# Trained and tested combination 121, taking 12.67 seconds
#
# Trained and tested combination 122, taking 18.93 seconds
#
# Trained and tested combination 123, taking 16.87 seconds
#
# Trained and tested combination 124, taking 25.23 seconds
#
# Trained and tested combination 125, taking 12.67 seconds
#
# Trained and tested combination 126, taking 18.93 seconds
#
# Trained and tested combination 127, taking 16.87 seconds
#
# Trained and tested combination 128, taking 25.24 seconds
#
# Trained and tested combination 129, taking 12.68 seconds
#
# Trained and tested combination 130, taking 18.94 seconds
#
# Trained and tested combination 131, taking 16.94 seconds
#
# Trained and tested combination 132, taking 25.33 seconds
#
# Trained and tested combination 133, taking 12.67 seconds
#
# Trained and tested combination 134, taking 18.94 seconds
#
# Trained and tested combination 135, taking 16.88 seconds
#
# Trained and tested combination 136, taking 25.38 seconds
#
# Trained and tested combination 137, taking 12.8 seconds
#
# Trained and tested combination 138, taking 19.16 seconds
#
# Trained and tested combination 139, taking 17.1 seconds
#
# Trained and tested combination 140, taking 25.53 seconds
#
# Trained and tested combination 141, taking 12.81 seconds
#
# Trained and tested combination 142, taking 19.09 seconds
#
# Trained and tested combination 143, taking 17.0 seconds
#
# Trained and tested combination 144, taking 25.26 seconds
#
# Trained and tested combination 145, taking 24.65 seconds
#
# Trained and tested combination 146, taking 36.67 seconds
#
# Trained and tested combination 147, taking 32.71 seconds
#
# Trained and tested combination 148, taking 48.97 seconds
#
# Trained and tested combination 149, taking 24.44 seconds
#
# Trained and tested combination 150, taking 36.62 seconds
#
# Trained and tested combination 151, taking 32.7 seconds
#
# Trained and tested combination 152, taking 48.98 seconds
#
# Trained and tested combination 153, taking 24.46 seconds
#
# Trained and tested combination 154, taking 36.61 seconds
#
# Trained and tested combination 155, taking 32.7 seconds
#
# Trained and tested combination 156, taking 49.16 seconds
#
# Trained and tested combination 157, taking 27.53 seconds
#
# Trained and tested combination 158, taking 37.01 seconds
#
# Trained and tested combination 159, taking 32.98 seconds
#
# Trained and tested combination 160, taking 49.34 seconds
#
# Trained and tested combination 161, taking 24.64 seconds
#
# Trained and tested combination 162, taking 36.88 seconds
#
# Trained and tested combination 163, taking 32.94 seconds
#
# Trained and tested combination 164, taking 49.32 seconds
#
# Trained and tested combination 165, taking 24.65 seconds
#
# Trained and tested combination 166, taking 36.87 seconds
#
# Trained and tested combination 167, taking 32.95 seconds
#
# Trained and tested combination 168, taking 49.35 seconds
#
# Trained and tested combination 169, taking 46.06 seconds
#
# Trained and tested combination 170, taking 69.69 seconds
#
# Trained and tested combination 171, taking 63.07 seconds
#
# Trained and tested combination 172, taking 96.73 seconds
#
# Trained and tested combination 173, taking 46.53 seconds
#
# Trained and tested combination 174, taking 70.38 seconds
#
# Trained and tested combination 175, taking 63.43 seconds
#
# Trained and tested combination 176, taking 96.76 seconds
#
# Trained and tested combination 177, taking 46.18 seconds
#
# Trained and tested combination 178, taking 69.69 seconds
#
# Trained and tested combination 179, taking 62.93 seconds
#
# Trained and tested combination 180, taking 874.64 seconds
#
# Trained and tested combination 181, taking 46.08 seconds
#
# Trained and tested combination 182, taking 70.17 seconds
#
# Trained and tested combination 183, taking 63.28 seconds
#
# Trained and tested combination 184, taking 96.53 seconds
#
# Trained and tested combination 185, taking 45.77 seconds
#
# Trained and tested combination 186, taking 69.21 seconds
#
# Trained and tested combination 187, taking 62.64 seconds
#
# Trained and tested combination 188, taking 95.79 seconds
#
# Trained and tested combination 189, taking 45.74 seconds
#
# Trained and tested combination 190, taking 69.21 seconds
#
# Trained and tested combination 191, taking 62.65 seconds
#
# Trained and tested combination 192, taking 95.85 seconds
#
# Trained and tested combination 193, taking 46.2 seconds
#
# Trained and tested combination 194, taking 70.0 seconds
#
# Trained and tested combination 195, taking 63.79 seconds
#
# Trained and tested combination 196, taking 98.28 seconds
#
# Trained and tested combination 197, taking 46.31 seconds
#
# Trained and tested combination 198, taking 129.56 seconds
#
# Trained and tested combination 199, taking 64.06 seconds
#
# Trained and tested combination 200, taking 99.78 seconds
#
# Trained and tested combination 201, taking 46.77 seconds
#
# Trained and tested combination 202, taking 70.8 seconds
#
# Trained and tested combination 203, taking 64.56 seconds
#
# Trained and tested combination 204, taking 99.27 seconds
#
# Trained and tested combination 205, taking 46.77 seconds
#
# Trained and tested combination 206, taking 70.78 seconds
#
# Trained and tested combination 207, taking 64.55 seconds
#
# Trained and tested combination 208, taking 99.26 seconds
#
# Trained and tested combination 209, taking 46.78 seconds
#
# Trained and tested combination 210, taking 70.82 seconds
#
# Trained and tested combination 211, taking 64.57 seconds
#
# Trained and tested combination 212, taking 99.3 seconds
#
# Trained and tested combination 213, taking 46.8 seconds
#
# Trained and tested combination 214, taking 70.83 seconds
#
# Trained and tested combination 215, taking 64.94 seconds
#
# Trained and tested combination 216, taking 99.51 seconds
#
# Trained and tested combination 217, taking 46.68 seconds
#
# Trained and tested combination 218, taking 70.8 seconds
#
# Trained and tested combination 219, taking 64.11 seconds
#
# Trained and tested combination 220, taking 99.09 seconds
#
# Trained and tested combination 221, taking 46.52 seconds
#
# Trained and tested combination 222, taking 70.4 seconds
#
# Trained and tested combination 223, taking 64.48 seconds
#
# Trained and tested combination 224, taking 99.18 seconds
#
# Trained and tested combination 225, taking 46.72 seconds
#
# Trained and tested combination 226, taking 70.72 seconds
#
# Trained and tested combination 227, taking 64.48 seconds
#
# Trained and tested combination 228, taking 99.16 seconds
#
# Trained and tested combination 229, taking 46.71 seconds
#
# Trained and tested combination 230, taking 70.62 seconds
#
# Trained and tested combination 231, taking 64.29 seconds
#
# Trained and tested combination 232, taking 98.8 seconds
#
# Trained and tested combination 233, taking 46.56 seconds
#
# Trained and tested combination 234, taking 70.41 seconds
#
# Trained and tested combination 235, taking 64.25 seconds
#
# Trained and tested combination 236, taking 98.79 seconds
#
# Trained and tested combination 237, taking 46.71 seconds
#
# Trained and tested combination 238, taking 71.78 seconds
#
# Trained and tested combination 239, taking 64.35 seconds
#
# Trained and tested combination 240, taking 99.32 seconds
