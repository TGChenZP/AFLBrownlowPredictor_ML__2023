# %%
from ZhongShan import *
import pickle
import copy
import numpy as np
import json

# %%
class JiaoCheng:

    def __init__(self, sanmin):
        """ Initialise class """
        self.sanmin = sanmin
        self._initialise_objects()

        print('JiaoCheng Initialised')



    def _initialise_objects(self):
        pass
    

    
    def get_feature_combinations(self, score_type, label, penalty_function_type, export_address = None):
        """ Function that gets combinations based on JiaoCheng's algorithm along with its score, based on
        inputted score type, label and penalty function type. Has option to export"""

        if score_type not in ('NMI', 'Abs Corr'):
            print("score_type should be either 'NMI' or 'Abs Corr'")
            return
        
        if label not in self.sanmin.label_columns:
            print("label should be in the designated labels column")
            return

        if penalty_function_type not in ('None', 'Mean', 'Max'):
            print("penalty_function_type should be either 'None' or 'Mean' or 'Max'")
            return

        # get the correct matrix
        if score_type == 'Abs Corr':
            score_matrix = self.sanmin.abs_corr_matrix
        elif score_type == 'NMI':
            score_matrix = self.sanmin.NMI_matrix
            
        # get the correct penalty function
        if penalty_function_type == 'None':
            funct = self._return_zero
        elif penalty_function_type == 'Mean':
            funct = np.mean
        elif penalty_function_type == 'Max':
            funct = max

        # object to output
        feature_combos_with_score = list()

        # starting with each individual feature
        for feature in self.sanmin.final_features[label]:
            if feature in self.sanmin.label_columns: # don't add if it is a label
                continue

            # initial current combo
            curr_combo = [feature]

            # initial current score
            curr_combo_score = score_matrix.loc[feature][label]

            # initial combo appended with its score
            feature_combos_with_score.append((copy.deepcopy(curr_combo), curr_combo_score))

            switch = True

            while switch is True:

                # temporary scores
                curr_added_value = 0
                curr_feature_to_add = None

                # for all try-able combinations
                for candidate_feature in self.sanmin.final_features[label]: 
                    if candidate_feature in curr_combo or candidate_feature in self.sanmin.label_columns: # don't try those already in, nor those that are labels
                        continue
                    
                    # get candidate's own corr with label
                    candidate_feature_score = score_matrix.loc[candidate_feature][label]

                    # get list of corr between candidate and features currently in combo
                    candidate_feature_relation_scores = list()
                    for curr_combo_feature in curr_combo:
                        candidate_feature_relation_scores.append(score_matrix.loc[candidate_feature][curr_combo_feature])
                    
                    # if candidate score - penalty > current best, then accept; else, don't accept
                    if candidate_feature_score - funct(candidate_feature_relation_scores) >= curr_added_value:
                        curr_added_value = candidate_feature_score - funct(candidate_feature_relation_scores)
                        curr_feature_to_add = candidate_feature

                # if managed to add something to combo, then continue loop and add to overall list, else break this loop
                if curr_feature_to_add is None:
                    switch = False

                else:
                    curr_combo.append(curr_feature_to_add)
                    curr_combo_score += curr_added_value
                    feature_combos_with_score.append((copy.deepcopy(curr_combo), curr_combo_score))

        # Remove duplicates and sort
        feature_combos_with_score = self._features_duplicate_removal(feature_combos_with_score)
        feature_combos_with_score.sort(key = lambda x: x[1])

        # Get pure feature combinations, and scores of feature combinations
        feature_combo = [feature_combo[0] for feature_combo in feature_combos_with_score]
        feature_combo_scores = [feature_combo[1] for feature_combo in feature_combos_with_score]

        print(f"{len(feature_combos_with_score)} feature combinations, with combo scores ranging from {round(feature_combo_scores[0], 4)} to {round(feature_combo_scores[-1], 4)}")
        

        # Export combinations and scores as a json
        if export_address:
            json_output = {'feature_combos_with_score': feature_combos_with_score, 
                            'feature_combo': feature_combo, 
                            'feature_combo_scores': feature_combo_scores}
            
            export_address_strip = export_address.split('.json')[0]
            with open(f'{export_address_strip}.json', 'w') as f:
                json.dump(json_output, f, indent=2) 
            print("Export Completed")
    
        return feature_combos_with_score, feature_combo, feature_combo_scores


    def _return_zero(self, dummy):
        """ Helper function that returns 0 for penalty, no matter input """
        return 0
    


    def _features_duplicate_removal(self, feature_combos_with_score):
        """ Helper function that remove duplicate combinations """
        for i in range(len(feature_combos_with_score)):
            feature_combos_with_score[i][0].sort()

        feature_combos_with_score.sort(key = lambda x:x[0])

        duplicate_i = []

        feature_combos_no_duplicates = []

        for i in range(len(feature_combos_with_score)-1):
            if i in duplicate_i:
                continue

            if feature_combos_with_score[i][0] == feature_combos_with_score[i+1][0]:
                # retain the higher score
                if feature_combos_with_score[i][1] >= feature_combos_with_score[i+1][1]:
                    duplicate_i.append(i)
                else:
                    duplicate_i.append(i+1)
            
            if i not in duplicate_i:
                feature_combos_no_duplicates.append(feature_combos_with_score[i])

        return feature_combos_no_duplicates

# %%
with open(f'../models/AFL_pipeline_N.pickle', 'rb') as f:
    sanmin = pickle.load(f)

# %%
jiaocheng = JiaoCheng(sanmin)
# Out:
# JiaoCheng Initialised

# %%
jiaocheng.get_feature_combinations('Abs Corr', '3', 'None')
# Out:
# 509 feature combinations, with combo scores ranging from 0.1032 to 5.064
# ([(['Turnovers OTN'], 0.10316544698694283),
#   (['Goals OTN'], 0.10886208663416339),
#   (['Inside 50s OTN'], 0.13002293606485546),
#   (['Goals BTN'], 0.13565476960151918),
#   (['Centre Clearances OTN'], 0.13770105165882007),
#   (['Centre Clearances BTN'], 0.14152820747598335),
#   (['Inside 50s BTN'], 0.14308112544540835),
#   (['Metres Gained OTN'], 0.15156546898451054),
#   (['Ineffective Disposals OTN'], 0.15164889494661338),
#   (['Handballs OTN'], 0.1551428890082802),
#   (['Ineffective Disposals BTN'], 0.15545990241590668),
#   (['Uncontested Possessions BTN'], 0.15591445740848697),
#   (['Stoppage Clearances OTN'], 0.1576606898100344),
#   (['Stoppage Clearances BTN'], 0.16299124874713072),
#   (['Metres Gained BTN'], 0.16305155629037155),
#   (['Behind Assists OTN'], 0.163181910722418),
#   (['Score Involvements OTN'], 0.16385626043781992),
#   (['Handballs BTN'], 0.16592597635834477),
#   (['Kicks OTN'], 0.17078354891440012),
#   (['Clearances OTN'], 0.17148996477984982),
#   (['Clearances BTN'], 0.1788008724853846),
#   (['Kicks BTN'], 0.18337577801443472),
#   (['Effective Disposals OTN'], 0.18452914953668476),
#   (['Behind Assists BTN'], 0.18640217993629193),
#   (['Contested Possessions OTN'], 0.18735825633965128),
#   (['Score Involvements BTN'], 0.18963416682561665),
#   (['Contested Possessions BTN'], 0.19935866417930653),
#   (['Effective Disposals BTN'], 0.19953328615371319),
#   (['Disposals OTN'], 0.2044956509887481),
#   (['Disposals BTN'], 0.21821015450326617),
#   (['Disposals BTN', 'Turnovers OTN'], 0.321375601490209),
#   (['Disposals BTN', 'Goals OTN'], 0.32707224113742955),
#   (['Disposals BTN', 'Inside 50s OTN'], 0.34823309056812163),
#   (['Disposals BTN', 'Goals BTN'], 0.3538649241047853),
#   (['Centre Clearances OTN', 'Disposals BTN'], 0.35591120616208627),
#   (['Centre Clearances BTN', 'Disposals BTN'], 0.3597383619792495),
#   (['Disposals BTN', 'Inside 50s BTN'], 0.3612912799486745),
#   (['Disposals BTN', 'Uncontested Possessions OTN'], 0.3618310405665883),
#   (['Disposals BTN', 'Metres Gained OTN'], 0.3697756234877767),
#   (['Disposals BTN', 'Ineffective Disposals OTN'], 0.3698590494498796),
#   (['Disposals BTN', 'Handballs OTN'], 0.37335304351154636),
#   (['Disposals BTN', 'Ineffective Disposals BTN'], 0.3736700569191729),
#   (['Disposals BTN', 'Uncontested Possessions BTN'], 0.37412461191175317),
#   (['Disposals BTN', 'Stoppage Clearances OTN'], 0.37587084431330053),
#   (['Disposals BTN', 'Stoppage Clearances BTN'], 0.38120140325039686),
#   (['Disposals BTN', 'Metres Gained BTN'], 0.3812617107936377),
#   (['Behind Assists OTN', 'Disposals BTN'], 0.38139206522568414),
#   (['Disposals BTN', 'Score Involvements OTN'], 0.38206641494108606),
#   (['Disposals BTN', 'Handballs BTN'], 0.3841361308616109),
#   (['Disposals BTN', 'Kicks OTN'], 0.38899370341766626),
#   (['Clearances OTN', 'Disposals BTN'], 0.389700119283116),
#   (['Clearances BTN', 'Disposals BTN'], 0.39701102698865076),
#   (['Disposals BTN', 'Kicks BTN'], 0.4015859325177009),
#   (['Disposals BTN', 'Effective Disposals OTN'], 0.40273930403995095),
#   (['Behind Assists BTN', 'Disposals BTN'], 0.40461233443955813),
#   (['Contested Possessions OTN', 'Disposals BTN'], 0.40556841084291745),
#   (['Disposals BTN', 'Score Involvements BTN'], 0.4078443213288828),
#   (['Contested Possessions BTN', 'Disposals BTN'], 0.4175688186825727),
#   (['Disposals BTN', 'Effective Disposals BTN'], 0.4177434406569793),
#   (['Disposals BTN', 'Disposals OTN'], 0.4227058054920143),
#   (['Disposals BTN', 'Disposals OTN', 'Turnovers OTN'], 0.525871252478957),
#   (['Disposals BTN', 'Disposals OTN', 'Goals OTN'], 0.5315678921261777),
#   (['Disposals BTN', 'Disposals OTN', 'Inside 50s OTN'], 0.5527287415568698),
#   (['Disposals BTN', 'Disposals OTN', 'Goals BTN'], 0.5583605750935334),
#   (['Centre Clearances OTN', 'Disposals BTN', 'Disposals OTN'],
#    0.5604068571508344),
#   (['Centre Clearances BTN', 'Disposals BTN', 'Disposals OTN'],
#    0.5642340129679977),
#   (['Disposals BTN', 'Disposals OTN', 'Inside 50s BTN'], 0.5657869309374226),
#   (['Disposals BTN', 'Disposals OTN', 'Uncontested Possessions OTN'],
#    0.5663266915553364),
#   (['Disposals BTN', 'Disposals OTN', 'Metres Gained OTN'],
#    0.5742712744765248),
#   (['Disposals BTN', 'Disposals OTN', 'Ineffective Disposals OTN'],
#    0.5743547004386277),
#   (['Disposals BTN', 'Disposals OTN', 'Handballs OTN'], 0.5778486945002945),
#   (['Disposals BTN', 'Disposals OTN', 'Ineffective Disposals BTN'],
#    0.578165707907921),
#   (['Disposals BTN', 'Disposals OTN', 'Uncontested Possessions BTN'],
#    0.5786202629005013),
#   (['Disposals BTN', 'Disposals OTN', 'Stoppage Clearances OTN'],
#    0.5803664953020486),
#   (['Disposals BTN', 'Disposals OTN', 'Stoppage Clearances BTN'],
#    0.585697054239145),
#   (['Disposals BTN', 'Disposals OTN', 'Metres Gained BTN'],
#    0.5857573617823858),
#   (['Behind Assists OTN', 'Disposals BTN', 'Disposals OTN'],
#    0.5858877162144323),
#   (['Disposals BTN', 'Disposals OTN', 'Score Involvements OTN'],
#    0.5865620659298342),
#   (['Disposals BTN', 'Disposals OTN', 'Handballs BTN'], 0.588631781850359),
#   (['Disposals BTN', 'Disposals OTN', 'Kicks OTN'], 0.5934893544064144),
#   (['Clearances OTN', 'Disposals BTN', 'Disposals OTN'], 0.5941957702718641),
#   (['Clearances BTN', 'Disposals BTN', 'Disposals OTN'], 0.6015066779773989),
#   (['Disposals BTN', 'Disposals OTN', 'Kicks BTN'], 0.606081583506449),
#   (['Disposals BTN', 'Disposals OTN', 'Effective Disposals OTN'],
#    0.6072349550286991),
#   (['Behind Assists BTN', 'Disposals BTN', 'Disposals OTN'],
#    0.6091079854283062),
#   (['Contested Possessions OTN', 'Disposals BTN', 'Disposals OTN'],
#    0.6100640618316655),
#   (['Disposals BTN', 'Disposals OTN', 'Score Involvements BTN'],
#    0.6123399723176309),
#   (['Contested Possessions BTN', 'Disposals BTN', 'Disposals OTN'],
#    0.6220644696713208),
#   (['Disposals BTN', 'Disposals OTN', 'Effective Disposals BTN'],
#    0.6222390916457274),
#   (['Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Turnovers OTN'],
#    0.7254045386326702),
#   (['Disposals BTN', 'Disposals OTN', 'Effective Disposals BTN', 'Goals OTN'],
#    0.7311011782798909),
#   (['Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Inside 50s OTN'],
#    0.7522620277105829),
#   (['Disposals BTN', 'Disposals OTN', 'Effective Disposals BTN', 'Goals BTN'],
#    0.7578938612472466),
#   (['Centre Clearances OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN'],
#    0.7599401433045476),
#   (['Centre Clearances BTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN'],
#    0.7637672991217108),
#   (['Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Inside 50s BTN'],
#    0.7653202170911357),
#   (['Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Uncontested Possessions OTN'],
#    0.7658599777090496),
#   (['Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Metres Gained OTN'],
#    0.773804560630238),
#   (['Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Ineffective Disposals OTN'],
#    0.7738879865923409),
#   (['Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Handballs OTN'],
#    0.7773819806540077),
#   (['Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Ineffective Disposals BTN'],
#    0.7776989940616341),
#   (['Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Uncontested Possessions BTN'],
#    0.7781535490542144),
#   (['Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Stoppage Clearances OTN'],
#    0.7798997814557618),
#   (['Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Stoppage Clearances BTN'],
#    0.7852303403928582),
#   (['Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Metres Gained BTN'],
#    0.785290647936099),
#   (['Behind Assists OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN'],
#    0.7854210023681454),
#   (['Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Score Involvements OTN'],
#    0.7860953520835474),
#   (['Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Handballs BTN'],
#    0.7881650680040722),
#   (['Disposals BTN', 'Disposals OTN', 'Effective Disposals BTN', 'Kicks OTN'],
#    0.7930226405601275),
#   (['Clearances OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN'],
#    0.7937290564255772),
#   (['Clearances BTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN'],
#    0.8010399641311121),
#   (['Disposals BTN', 'Disposals OTN', 'Effective Disposals BTN', 'Kicks BTN'],
#    0.8056148696601622),
#   (['Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Effective Disposals OTN'],
#    0.8067682411824122),
#   (['Behind Assists BTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN'],
#    0.8086412715820195),
#   (['Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN'],
#    0.8095973479853786),
#   (['Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Score Involvements BTN'],
#    0.8118732584713442),
#   (['Contested Possessions BTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN'],
#    0.821597755825034),
#   (['Contested Possessions BTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Turnovers OTN'],
#    0.9247632028119768),
#   (['Contested Possessions BTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Goals OTN'],
#    0.9304598424591974),
#   (['Contested Possessions BTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Inside 50s OTN'],
#    0.9516206918898895),
#   (['Contested Possessions BTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Goals BTN'],
#    0.9572525254265531),
#   (['Centre Clearances OTN',
#     'Contested Possessions BTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN'],
#    0.9592988074838542),
#   (['Centre Clearances BTN',
#     'Contested Possessions BTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN'],
#    0.9631259633010174),
#   (['Contested Possessions BTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Inside 50s BTN'],
#    0.9646788812704423),
#   (['Contested Possessions BTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Uncontested Possessions OTN'],
#    0.9652186418883562),
#   (['Contested Possessions BTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Metres Gained OTN'],
#    0.9731632248095445),
#   (['Contested Possessions BTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Ineffective Disposals OTN'],
#    0.9732466507716475),
#   (['Contested Possessions BTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Handballs OTN'],
#    0.9767406448333142),
#   (['Contested Possessions BTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Ineffective Disposals BTN'],
#    0.9770576582409407),
#   (['Contested Possessions BTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Uncontested Possessions BTN'],
#    0.977512213233521),
#   (['Contested Possessions BTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Stoppage Clearances OTN'],
#    0.9792584456350684),
#   (['Contested Possessions BTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Stoppage Clearances BTN'],
#    0.9845890045721648),
#   (['Contested Possessions BTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Metres Gained BTN'],
#    0.9846493121154056),
#   (['Behind Assists OTN',
#     'Contested Possessions BTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN'],
#    0.984779666547452),
#   (['Contested Possessions BTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Score Involvements OTN'],
#    0.985454016262854),
#   (['Contested Possessions BTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Handballs BTN'],
#    0.9875237321833787),
#   (['Contested Possessions BTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Kicks OTN'],
#    0.9923813047394341),
#   (['Clearances OTN',
#     'Contested Possessions BTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN'],
#    0.9930877206048838),
#   (['Clearances BTN',
#     'Contested Possessions BTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN'],
#    1.0003986283104187),
#   (['Contested Possessions BTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Kicks BTN'],
#    1.0049735338394687),
#   (['Contested Possessions BTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Effective Disposals OTN'],
#    1.0061269053617188),
#   (['Behind Assists BTN',
#     'Contested Possessions BTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN'],
#    1.007999935761326),
#   (['Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN'],
#    1.0089560121646852),
#   (['Contested Possessions BTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Score Involvements BTN'],
#    1.0112319226506508),
#   (['Contested Possessions BTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Score Involvements BTN',
#     'Turnovers OTN'],
#    1.1143973696375935),
#   (['Contested Possessions BTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Goals OTN',
#     'Score Involvements BTN'],
#    1.1200940092848142),
#   (['Contested Possessions BTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Inside 50s OTN',
#     'Score Involvements BTN'],
#    1.1412548587155062),
#   (['Contested Possessions BTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Goals BTN',
#     'Score Involvements BTN'],
#    1.1468866922521699),
#   (['Centre Clearances OTN',
#     'Contested Possessions BTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Score Involvements BTN'],
#    1.148932974309471),
#   (['Centre Clearances BTN',
#     'Contested Possessions BTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Score Involvements BTN'],
#    1.1527601301266341),
#   (['Contested Possessions BTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Inside 50s BTN',
#     'Score Involvements BTN'],
#    1.154313048096059),
#   (['Contested Possessions BTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Score Involvements BTN',
#     'Uncontested Possessions OTN'],
#    1.154852808713973),
#   (['Contested Possessions BTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Metres Gained OTN',
#     'Score Involvements BTN'],
#    1.1627973916351613),
#   (['Contested Possessions BTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Ineffective Disposals OTN',
#     'Score Involvements BTN'],
#    1.1628808175972642),
#   (['Contested Possessions BTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Handballs OTN',
#     'Score Involvements BTN'],
#    1.166374811658931),
#   (['Contested Possessions BTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Ineffective Disposals BTN',
#     'Score Involvements BTN'],
#    1.1666918250665574),
#   (['Contested Possessions BTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Score Involvements BTN',
#     'Uncontested Possessions BTN'],
#    1.1671463800591377),
#   (['Contested Possessions BTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Score Involvements BTN',
#     'Stoppage Clearances OTN'],
#    1.168892612460685),
#   (['Contested Possessions BTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Score Involvements BTN',
#     'Stoppage Clearances BTN'],
#    1.1742231713977815),
#   (['Contested Possessions BTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Metres Gained BTN',
#     'Score Involvements BTN'],
#    1.1742834789410224),
#   (['Behind Assists OTN',
#     'Contested Possessions BTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Score Involvements BTN'],
#    1.1744138333730687),
#   (['Contested Possessions BTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Score Involvements BTN',
#     'Score Involvements OTN'],
#    1.1750881830884707),
#   (['Contested Possessions BTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Handballs BTN',
#     'Score Involvements BTN'],
#    1.1771578990089955),
#   (['Contested Possessions BTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Kicks OTN',
#     'Score Involvements BTN'],
#    1.1820154715650508),
#   (['Clearances OTN',
#     'Contested Possessions BTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Score Involvements BTN'],
#    1.1827218874305006),
#   (['Clearances BTN',
#     'Contested Possessions BTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Score Involvements BTN'],
#    1.1900327951360354),
#   (['Contested Possessions BTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Kicks BTN',
#     'Score Involvements BTN'],
#    1.1946077006650855),
#   (['Contested Possessions BTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Effective Disposals OTN',
#     'Score Involvements BTN'],
#    1.1957610721873355),
#   (['Behind Assists BTN',
#     'Contested Possessions BTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Score Involvements BTN'],
#    1.1976341025869428),
#   (['Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Score Involvements BTN'],
#    1.198590178990302),
#   (['Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Score Involvements BTN',
#     'Turnovers OTN'],
#    1.3017556259772447),
#   (['Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Goals OTN',
#     'Score Involvements BTN'],
#    1.3074522656244654),
#   (['Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Inside 50s OTN',
#     'Score Involvements BTN'],
#    1.3286131150551574),
#   (['Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Goals BTN',
#     'Score Involvements BTN'],
#    1.334244948591821),
#   (['Centre Clearances OTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Score Involvements BTN'],
#    1.3362912306491221),
#   (['Centre Clearances BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Score Involvements BTN'],
#    1.3401183864662853),
#   (['Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Inside 50s BTN',
#     'Score Involvements BTN'],
#    1.3416713044357103),
#   (['Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Score Involvements BTN',
#     'Uncontested Possessions OTN'],
#    1.342211065053624),
#   (['Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Metres Gained OTN',
#     'Score Involvements BTN'],
#    1.3501556479748125),
#   (['Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Ineffective Disposals OTN',
#     'Score Involvements BTN'],
#    1.3502390739369154),
#   (['Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Handballs OTN',
#     'Score Involvements BTN'],
#    1.3537330679985822),
#   (['Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Ineffective Disposals BTN',
#     'Score Involvements BTN'],
#    1.3540500814062086),
#   (['Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Score Involvements BTN',
#     'Uncontested Possessions BTN'],
#    1.354504636398789),
#   (['Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Score Involvements BTN',
#     'Stoppage Clearances OTN'],
#    1.3562508688003363),
#   (['Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Score Involvements BTN',
#     'Stoppage Clearances BTN'],
#    1.3615814277374327),
#   (['Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Metres Gained BTN',
#     'Score Involvements BTN'],
#    1.3616417352806736),
#   (['Behind Assists OTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Score Involvements BTN'],
#    1.36177208971272),
#   (['Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Score Involvements BTN',
#     'Score Involvements OTN'],
#    1.362446439428122),
#   (['Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Handballs BTN',
#     'Score Involvements BTN'],
#    1.3645161553486467),
#   (['Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Kicks OTN',
#     'Score Involvements BTN'],
#    1.369373727904702),
#   (['Clearances OTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Score Involvements BTN'],
#    1.3700801437701517),
#   (['Clearances BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Score Involvements BTN'],
#    1.3773910514756866),
#   (['Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Kicks BTN',
#     'Score Involvements BTN'],
#    1.3819659570047367),
#   (['Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Effective Disposals OTN',
#     'Score Involvements BTN'],
#    1.3831193285269867),
#   (['Behind Assists BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Score Involvements BTN'],
#    1.3849923589265938),
#   (['Behind Assists BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Score Involvements BTN',
#     'Turnovers OTN'],
#    1.4881578059135365),
#   (['Behind Assists BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Goals OTN',
#     'Score Involvements BTN'],
#    1.4938544455607574),
#   (['Behind Assists BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Inside 50s OTN',
#     'Score Involvements BTN'],
#    1.5150152949914495),
#   (['Behind Assists BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Goals BTN',
#     'Score Involvements BTN'],
#    1.520647128528113),
#   (['Behind Assists BTN',
#     'Centre Clearances OTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Score Involvements BTN'],
#    1.522693410585414),
#   (['Behind Assists BTN',
#     'Centre Clearances BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Score Involvements BTN'],
#    1.5265205664025774),
#   (['Behind Assists BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Inside 50s BTN',
#     'Score Involvements BTN'],
#    1.528073484372002),
#   (['Behind Assists BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Score Involvements BTN',
#     'Uncontested Possessions OTN'],
#    1.528613244989916),
#   (['Behind Assists BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Metres Gained OTN',
#     'Score Involvements BTN'],
#    1.5365578279111043),
#   (['Behind Assists BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Ineffective Disposals OTN',
#     'Score Involvements BTN'],
#    1.5366412538732073),
#   (['Behind Assists BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Handballs OTN',
#     'Score Involvements BTN'],
#    1.5401352479348742),
#   (['Behind Assists BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Ineffective Disposals BTN',
#     'Score Involvements BTN'],
#    1.5404522613425007),
#   (['Behind Assists BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Score Involvements BTN',
#     'Uncontested Possessions BTN'],
#    1.540906816335081),
#   (['Behind Assists BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Score Involvements BTN',
#     'Stoppage Clearances OTN'],
#    1.5426530487366281),
#   (['Behind Assists BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Score Involvements BTN',
#     'Stoppage Clearances BTN'],
#    1.5479836076737246),
#   (['Behind Assists BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Metres Gained BTN',
#     'Score Involvements BTN'],
#    1.5480439152169656),
#   (['Behind Assists BTN',
#     'Behind Assists OTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Score Involvements BTN'],
#    1.548174269649012),
#   (['Behind Assists BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Score Involvements BTN',
#     'Score Involvements OTN'],
#    1.548848619364414),
#   (['Behind Assists BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Handballs BTN',
#     'Score Involvements BTN'],
#    1.5509183352849387),
#   (['Behind Assists BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Kicks OTN',
#     'Score Involvements BTN'],
#    1.555775907840994),
#   (['Behind Assists BTN',
#     'Clearances OTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Score Involvements BTN'],
#    1.5564823237064438),
#   (['Behind Assists BTN',
#     'Clearances BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Score Involvements BTN'],
#    1.5637932314119785),
#   (['Behind Assists BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Kicks BTN',
#     'Score Involvements BTN'],
#    1.5683681369410287),
#   (['Behind Assists BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Effective Disposals OTN',
#     'Score Involvements BTN'],
#    1.5695215084632785),
#   (['Behind Assists BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Effective Disposals OTN',
#     'Score Involvements BTN',
#     'Turnovers OTN'],
#    1.6726869554502213),
#   (['Behind Assists BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Effective Disposals OTN',
#     'Goals OTN',
#     'Score Involvements BTN'],
#    1.6783835950974422),
#   (['Behind Assists BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Effective Disposals OTN',
#     'Inside 50s OTN',
#     'Score Involvements BTN'],
#    1.6995444445281342),
#   (['Behind Assists BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Effective Disposals OTN',
#     'Goals BTN',
#     'Score Involvements BTN'],
#    1.7051762780647977),
#   (['Behind Assists BTN',
#     'Centre Clearances OTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Effective Disposals OTN',
#     'Score Involvements BTN'],
#    1.7072225601220987),
#   (['Behind Assists BTN',
#     'Centre Clearances BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Effective Disposals OTN',
#     'Score Involvements BTN'],
#    1.7110497159392621),
#   (['Behind Assists BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Effective Disposals OTN',
#     'Inside 50s BTN',
#     'Score Involvements BTN'],
#    1.7126026339086868),
#   (['Behind Assists BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Effective Disposals OTN',
#     'Score Involvements BTN',
#     'Uncontested Possessions OTN'],
#    1.7131423945266007),
#   (['Behind Assists BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Effective Disposals OTN',
#     'Metres Gained OTN',
#     'Score Involvements BTN'],
#    1.721086977447789),
#   (['Behind Assists BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Effective Disposals OTN',
#     'Ineffective Disposals OTN',
#     'Score Involvements BTN'],
#    1.721170403409892),
#   (['Behind Assists BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Effective Disposals OTN',
#     'Handballs OTN',
#     'Score Involvements BTN'],
#    1.724664397471559),
#   (['Behind Assists BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Effective Disposals OTN',
#     'Ineffective Disposals BTN',
#     'Score Involvements BTN'],
#    1.7249814108791854),
#   (['Behind Assists BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Effective Disposals OTN',
#     'Score Involvements BTN',
#     'Uncontested Possessions BTN'],
#    1.7254359658717657),
#   (['Behind Assists BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Effective Disposals OTN',
#     'Score Involvements BTN',
#     'Stoppage Clearances OTN'],
#    1.7271821982733129),
#   (['Behind Assists BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Effective Disposals OTN',
#     'Score Involvements BTN',
#     'Stoppage Clearances BTN'],
#    1.7325127572104093),
#   (['Behind Assists BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Effective Disposals OTN',
#     'Metres Gained BTN',
#     'Score Involvements BTN'],
#    1.7325730647536504),
#   (['Behind Assists BTN',
#     'Behind Assists OTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Effective Disposals OTN',
#     'Score Involvements BTN'],
#    1.7327034191856967),
#   (['Behind Assists BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Effective Disposals OTN',
#     'Score Involvements BTN',
#     'Score Involvements OTN'],
#    1.7333777689010987),
#   (['Behind Assists BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Effective Disposals OTN',
#     'Handballs BTN',
#     'Score Involvements BTN'],
#    1.7354474848216235),
#   (['Behind Assists BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Effective Disposals OTN',
#     'Kicks OTN',
#     'Score Involvements BTN'],
#    1.7403050573776788),
#   (['Behind Assists BTN',
#     'Clearances OTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Effective Disposals OTN',
#     'Score Involvements BTN'],
#    1.7410114732431285),
#   (['Behind Assists BTN',
#     'Clearances BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Effective Disposals OTN',
#     'Score Involvements BTN'],
#    1.7483223809486632),
#   (['Behind Assists BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Effective Disposals OTN',
#     'Kicks BTN',
#     'Score Involvements BTN'],
#    1.7528972864777133),
#   (['Behind Assists BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Effective Disposals OTN',
#     'Kicks BTN',
#     'Score Involvements BTN',
#     'Turnovers OTN'],
#    1.856062733464656),
#   (['Behind Assists BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Effective Disposals OTN',
#     'Goals OTN',
#     'Kicks BTN',
#     'Score Involvements BTN'],
#    1.861759373111877),
#   (['Behind Assists BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Effective Disposals OTN',
#     'Inside 50s OTN',
#     'Kicks BTN',
#     'Score Involvements BTN'],
#    1.882920222542569),
#   (['Behind Assists BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Effective Disposals OTN',
#     'Goals BTN',
#     'Kicks BTN',
#     'Score Involvements BTN'],
#    1.8885520560792324),
#   (['Behind Assists BTN',
#     'Centre Clearances OTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Effective Disposals OTN',
#     'Kicks BTN',
#     'Score Involvements BTN'],
#    1.8905983381365334),
#   (['Behind Assists BTN',
#     'Centre Clearances BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Effective Disposals OTN',
#     'Kicks BTN',
#     'Score Involvements BTN'],
#    1.8944254939536969),
#   (['Behind Assists BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Effective Disposals OTN',
#     'Inside 50s BTN',
#     'Kicks BTN',
#     'Score Involvements BTN'],
#    1.8959784119231216),
#   (['Behind Assists BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Effective Disposals OTN',
#     'Kicks BTN',
#     'Score Involvements BTN',
#     'Uncontested Possessions OTN'],
#    1.8965181725410354),
#   (['Behind Assists BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Effective Disposals OTN',
#     'Kicks BTN',
#     'Metres Gained OTN',
#     'Score Involvements BTN'],
#    1.9044627554622238),
#   (['Behind Assists BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Effective Disposals OTN',
#     'Ineffective Disposals OTN',
#     'Kicks BTN',
#     'Score Involvements BTN'],
#    1.9045461814243267),
#   (['Behind Assists BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Effective Disposals OTN',
#     'Handballs OTN',
#     'Kicks BTN',
#     'Score Involvements BTN'],
#    1.9080401754859937),
#   (['Behind Assists BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Effective Disposals OTN',
#     'Ineffective Disposals BTN',
#     'Kicks BTN',
#     'Score Involvements BTN'],
#    1.9083571888936202),
#   (['Behind Assists BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Effective Disposals OTN',
#     'Kicks BTN',
#     'Score Involvements BTN',
#     'Uncontested Possessions BTN'],
#    1.9088117438862005),
#   (['Behind Assists BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Effective Disposals OTN',
#     'Kicks BTN',
#     'Score Involvements BTN',
#     'Stoppage Clearances OTN'],
#    1.9105579762877476),
#   (['Behind Assists BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Effective Disposals OTN',
#     'Kicks BTN',
#     'Score Involvements BTN',
#     'Stoppage Clearances BTN'],
#    1.915888535224844),
#   (['Behind Assists BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Effective Disposals OTN',
#     'Kicks BTN',
#     'Metres Gained BTN',
#     'Score Involvements BTN'],
#    1.915948842768085),
#   (['Behind Assists BTN',
#     'Behind Assists OTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Effective Disposals OTN',
#     'Kicks BTN',
#     'Score Involvements BTN'],
#    1.9160791972001314),
#   (['Behind Assists BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Effective Disposals OTN',
#     'Kicks BTN',
#     'Score Involvements BTN',
#     'Score Involvements OTN'],
#    1.9167535469155335),
#   (['Behind Assists BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Effective Disposals OTN',
#     'Handballs BTN',
#     'Kicks BTN',
#     'Score Involvements BTN'],
#    1.9188232628360582),
#   (['Behind Assists BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Effective Disposals OTN',
#     'Kicks BTN',
#     'Kicks OTN',
#     'Score Involvements BTN'],
#    1.9236808353921135),
#   (['Behind Assists BTN',
#     'Clearances OTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Effective Disposals OTN',
#     'Kicks BTN',
#     'Score Involvements BTN'],
#    1.9243872512575633),
#   (['Behind Assists BTN',
#     'Clearances BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Effective Disposals OTN',
#     'Kicks BTN',
#     'Score Involvements BTN'],
#    1.931698158963098),
#   (['Behind Assists BTN',
#     'Clearances BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Effective Disposals OTN',
#     'Kicks BTN',
#     'Score Involvements BTN',
#     'Turnovers OTN'],
#    2.0348636059500405),
#   (['Behind Assists BTN',
#     'Clearances BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Effective Disposals OTN',
#     'Goals OTN',
#     'Kicks BTN',
#     'Score Involvements BTN'],
#    2.0405602455972613),
#   (['Behind Assists BTN',
#     'Clearances BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Effective Disposals OTN',
#     'Inside 50s OTN',
#     'Kicks BTN',
#     'Score Involvements BTN'],
#    2.0617210950279534),
#   (['Behind Assists BTN',
#     'Clearances BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Effective Disposals OTN',
#     'Goals BTN',
#     'Kicks BTN',
#     'Score Involvements BTN'],
#    2.067352928564617),
#   (['Behind Assists BTN',
#     'Centre Clearances OTN',
#     'Clearances BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Effective Disposals OTN',
#     'Kicks BTN',
#     'Score Involvements BTN'],
#    2.069399210621918),
#   (['Behind Assists BTN',
#     'Centre Clearances BTN',
#     'Clearances BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Effective Disposals OTN',
#     'Kicks BTN',
#     'Score Involvements BTN'],
#    2.0732263664390813),
#   (['Behind Assists BTN',
#     'Clearances BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Effective Disposals OTN',
#     'Inside 50s BTN',
#     'Kicks BTN',
#     'Score Involvements BTN'],
#    2.074779284408506),
#   (['Behind Assists BTN',
#     'Clearances BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Effective Disposals OTN',
#     'Kicks BTN',
#     'Score Involvements BTN',
#     'Uncontested Possessions OTN'],
#    2.07531904502642),
#   (['Behind Assists BTN',
#     'Clearances BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Effective Disposals OTN',
#     'Kicks BTN',
#     'Metres Gained OTN',
#     'Score Involvements BTN'],
#    2.083263627947608),
#   (['Behind Assists BTN',
#     'Clearances BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Effective Disposals OTN',
#     'Ineffective Disposals OTN',
#     'Kicks BTN',
#     'Score Involvements BTN'],
#    2.083347053909711),
#   (['Behind Assists BTN',
#     'Clearances BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Effective Disposals OTN',
#     'Handballs OTN',
#     'Kicks BTN',
#     'Score Involvements BTN'],
#    2.086841047971378),
#   (['Behind Assists BTN',
#     'Clearances BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Effective Disposals OTN',
#     'Ineffective Disposals BTN',
#     'Kicks BTN',
#     'Score Involvements BTN'],
#    2.0871580613790046),
#   (['Behind Assists BTN',
#     'Clearances BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Effective Disposals OTN',
#     'Kicks BTN',
#     'Score Involvements BTN',
#     'Uncontested Possessions BTN'],
#    2.087612616371585),
#   (['Behind Assists BTN',
#     'Clearances BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Effective Disposals OTN',
#     'Kicks BTN',
#     'Score Involvements BTN',
#     'Stoppage Clearances OTN'],
#    2.089358848773132),
#   (['Behind Assists BTN',
#     'Clearances BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Effective Disposals OTN',
#     'Kicks BTN',
#     'Score Involvements BTN',
#     'Stoppage Clearances BTN'],
#    2.0946894077102285),
#   (['Behind Assists BTN',
#     'Clearances BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Effective Disposals OTN',
#     'Kicks BTN',
#     'Metres Gained BTN',
#     'Score Involvements BTN'],
#    2.0947497152534695),
#   (['Behind Assists BTN',
#     'Behind Assists OTN',
#     'Clearances BTN',
#     'Contested Possessions BTN',
#     'Contested Possessions OTN',
#     'Disposals BTN',
#     'Disposals OTN',
#     'Effective Disposals BTN',
#     'Effective Disposals OTN',
#     'Kicks BTN',
#     'Score Involvements BTN'],
#    2.094880069685516),
# ...
#    'Ineffective Disposals OTN',
#    'Inside 50s BTN',
#    'Inside 50s OTN',
#    'Kicks BTN',
#    'Kicks OTN',
#    'Metres Gained BTN',
#    'Metres Gained OTN',
#    'Score Involvements BTN',
#    'Score Involvements OTN',
#    'Stoppage Clearances BTN',
#    'Stoppage Clearances OTN',
#    'Uncontested Possessions BTN',
#    'Uncontested Possessions OTN'],
#   ['Behind Assists BTN',
#    'Behind Assists OTN',
#    'Centre Clearances BTN',
#    'Centre Clearances OTN',
#    'Clearances BTN',
#    'Clearances OTN',
#    'Contested Possessions BTN',
#    'Contested Possessions OTN',
#    'Disposals BTN',
#    'Disposals OTN',
#    'Effective Disposals BTN',
#    'Effective Disposals OTN',
#    'Goals BTN',
#    'Handballs BTN',
#    'Handballs OTN',
#    'Ineffective Disposals BTN',
#    'Ineffective Disposals OTN',
#    'Inside 50s BTN',
#    'Inside 50s OTN',
#    'Kicks BTN',
#    'Kicks OTN',
#    'Metres Gained BTN',
#    'Metres Gained OTN',
#    'Score Involvements BTN',
#    'Score Involvements OTN',
#    'Stoppage Clearances BTN',
#    'Stoppage Clearances OTN',
#    'Turnovers OTN',
#    'Uncontested Possessions BTN',
#    'Uncontested Possessions OTN'],
#   ['Behind Assists BTN',
#    'Behind Assists OTN',
#    'Centre Clearances BTN',
#    'Centre Clearances OTN',
#    'Clearances BTN',
#    'Clearances OTN',
#    'Contested Possessions BTN',
#    'Contested Possessions OTN',
#    'Disposals BTN',
#    'Disposals OTN',
#    'Effective Disposals BTN',
#    'Effective Disposals OTN',
#    'Goals BTN',
#    'Goals OTN',
#    'Handballs BTN',
#    'Handballs OTN',
#    'Ineffective Disposals BTN',
#    'Ineffective Disposals OTN',
#    'Inside 50s BTN',
#    'Inside 50s OTN',
#    'Kicks BTN',
#    'Kicks OTN',
#    'Metres Gained BTN',
#    'Metres Gained OTN',
#    'Score Involvements BTN',
#    'Score Involvements OTN',
#    'Stoppage Clearances BTN',
#    'Stoppage Clearances OTN',
#    'Uncontested Possessions BTN',
#    'Uncontested Possessions OTN'],
#   ['Behind Assists BTN',
#    'Behind Assists OTN',
#    'Centre Clearances BTN',
#    'Centre Clearances OTN',
#    'Clearances BTN',
#    'Clearances OTN',
#    'Contested Possessions BTN',
#    'Contested Possessions OTN',
#    'Disposals BTN',
#    'Disposals OTN',
#    'Effective Disposals BTN',
#    'Effective Disposals OTN',
#    'Goals BTN',
#    'Goals OTN',
#    'Handballs BTN',
#    'Handballs OTN',
#    'Ineffective Disposals BTN',
#    'Ineffective Disposals OTN',
#    'Inside 50s BTN',
#    'Inside 50s OTN',
#    'Kicks BTN',
#    'Kicks OTN',
#    'Metres Gained BTN',
#    'Metres Gained OTN',
#    'Score Involvements BTN',
#    'Score Involvements OTN',
#    'Stoppage Clearances BTN',
#    'Stoppage Clearances OTN',
#    'Uncontested Possessions BTN',
#    'Uncontested Possessions OTN'],
#   ['Behind Assists BTN',
#    'Behind Assists OTN',
#    'Centre Clearances BTN',
#    'Centre Clearances OTN',
#    'Clearances BTN',
#    'Clearances OTN',
#    'Contested Possessions BTN',
#    'Contested Possessions OTN',
#    'Disposals BTN',
#    'Disposals OTN',
#    'Effective Disposals BTN',
#    'Effective Disposals OTN',
#    'Goals BTN',
#    'Goals OTN',
#    'Handballs BTN',
#    'Handballs OTN',
#    'Ineffective Disposals BTN',
#    'Ineffective Disposals OTN',
#    'Inside 50s BTN',
#    'Inside 50s OTN',
#    'Kicks BTN',
#    'Kicks OTN',
#    'Metres Gained BTN',
#    'Metres Gained OTN',
#    'Score Involvements BTN',
#    'Score Involvements OTN',
#    'Stoppage Clearances BTN',
#    'Stoppage Clearances OTN',
#    'Turnovers OTN',
#    'Uncontested Possessions BTN',
#    'Uncontested Possessions OTN'],
#   ['Behind Assists BTN',
#    'Behind Assists OTN',
#    'Centre Clearances BTN',
#    'Centre Clearances OTN',
#    'Clearances BTN',
#    'Clearances OTN',
#    'Contested Possessions BTN',
#    'Contested Possessions OTN',
#    'Disposals BTN',
#    'Disposals OTN',
#    'Effective Disposals BTN',
#    'Effective Disposals OTN',
#    'Goals BTN',
#    'Goals OTN',
#    'Handballs BTN',
#    'Handballs OTN',
#    'Ineffective Disposals BTN',
#    'Ineffective Disposals OTN',
#    'Inside 50s BTN',
#    'Inside 50s OTN',
#    'Kicks BTN',
#    'Kicks OTN',
#    'Metres Gained BTN',
#    'Metres Gained OTN',
#    'Score Involvements BTN',
#    'Score Involvements OTN',
#    'Stoppage Clearances BTN',
#    'Stoppage Clearances OTN',
#    'Turnovers OTN',
#    'Uncontested Possessions BTN',
#    'Uncontested Possessions OTN'],
#   ['Behind Assists BTN',
#    'Behind Assists OTN',
#    'Centre Clearances BTN',
#    'Centre Clearances OTN',
#    'Clearances BTN',
#    'Clearances OTN',
#    'Contested Possessions BTN',
#    'Contested Possessions OTN',
#    'Disposals BTN',
#    'Disposals OTN',
#    'Effective Disposals BTN',
#    'Effective Disposals OTN',
#    'Goals BTN',
#    'Goals OTN',
#    'Handballs BTN',
#    'Handballs OTN',
#    'Ineffective Disposals BTN',
#    'Ineffective Disposals OTN',
#    'Inside 50s BTN',
#    'Inside 50s OTN',
#    'Kicks BTN',
#    'Kicks OTN',
#    'Metres Gained BTN',
#    'Metres Gained OTN',
#    'Score Involvements BTN',
#    'Score Involvements OTN',
#    'Stoppage Clearances BTN',
